# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanshi2023/Books-Python/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/hotel_bookings.csv")

# %%
dataset.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 55468     City Hotel            1        139               2016
# 53482     City Hotel            1          0               2016
# 81711     City Hotel            1        109               2016
# 5400    Resort Hotel            0        206               2016
# 9801    Resort Hotel            1         56               2017
# 77986     City Hotel            1         45               2015
# 94816     City Hotel            0        103               2016
# 68541     City Hotel            1        108               2017
# 110708    City Hotel            0         30               2017
# 111139    City Hotel            0         50               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 55468              August                        33
# 53482                June                        26
# 81711            February                         9
# ...

# %%
dataset.shape
# Out:
# (119390, 32)

# %%
dataset.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
dataset.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
dataset.describe(include="all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
import pandas as pd
import numpy as np

# %%
labels=['w','x','y','z']
sample_list=[100,200,300,400]
array=np.array([1,2,3,4])
dict={'w':10,'x':20,'y':30,'z':40}

# %%
pd.Series(data=sample_list)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
pd.Series(data=sample_list,index=labels)
# Out:
# w    100
# x    200
# y    300
# z    400
# dtype: int64

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
sports1=pd.Series([1,2,3,4],index=['cricket','football','basketball','golf'])
sports1
# Out:
# cricket       1
# football      2
# basketball    3
# golf          4
# dtype: int64

# %%
sports1['cricket']
# Out:
# 1

# %%
sports2=pd.Series([11,2,3,4],index=['cricket','football','baseball','golf'])
sports2
# Out:
# cricket     11
# football     2
# baseball     3
# golf         4
# dtype: int64

# %%
sports1+sports2
# Out:
# baseball       NaN
# basketball     NaN
# cricket       12.0
# football       4.0
# golf           8.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H'.split(),columns='Score1 Score2 Score3 Score4 Score5'.split())
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5
# A  0.654580  0.207913  0.840857  0.643734  0.601432
# B  0.743426  0.615079  0.947246  0.789670  0.012900
# C  0.497295  0.533593  0.144743  0.315837  0.984985
# D  0.547377  0.596336  0.317482  0.263124  0.715586
# E  0.710786  0.354063  0.095617  0.737343  0.100139
# F  0.410717  0.379094  0.192387  0.246458  0.093357
# G  0.585767  0.261465  0.601325  0.427820  0.494741
# H  0.009078  0.756148  0.109319  0.481513  0.051277

# %%
df1["Score3"]
# Out:
# A    0.840857
# B    0.947246
# C    0.144743
# D    0.317482
# E    0.095617
# F    0.192387
# G    0.601325
# H    0.109319
# Name: Score3, dtype: float64

# %%
df1[["Score1","Score2","Score3"]]
# Out:
#      Score1    Score2    Score3
# A  0.654580  0.207913  0.840857
# B  0.743426  0.615079  0.947246
# C  0.497295  0.533593  0.144743
# D  0.547377  0.596336  0.317482
# E  0.710786  0.354063  0.095617
# F  0.410717  0.379094  0.192387
# G  0.585767  0.261465  0.601325
# H  0.009078  0.756148  0.109319

# %%
df1['Score6']=df1['Score1']+df1['Score2']
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5    Score6
# A  0.654580  0.207913  0.840857  0.643734  0.601432  0.862494
# B  0.743426  0.615079  0.947246  0.789670  0.012900  1.358505
# C  0.497295  0.533593  0.144743  0.315837  0.984985  1.030888
# D  0.547377  0.596336  0.317482  0.263124  0.715586  1.143713
# E  0.710786  0.354063  0.095617  0.737343  0.100139  1.064848
# F  0.410717  0.379094  0.192387  0.246458  0.093357  0.789811
# G  0.585767  0.261465  0.601325  0.427820  0.494741  0.847232
# H  0.009078  0.756148  0.109319  0.481513  0.051277  0.765225

# %%
df2={'ID':['101','102','103','107','176'],'Name':['John','Mercy','Akash','Kavin','Lally'],'Profit':[20,54,56,87,123]}
df=pd.DataFrame(df2)
df
# Out:
#     ID   Name  Profit
# 0  101   John      20
# 1  102  Mercy      54
# 2  103  Akash      56
# 3  107  Kavin      87
# 4  176  Lally     123

# %%
df["ID"]
# Out:
# 0    101
# 1    102
# 2    103
# 3    107
# 4    176
# Name: ID, dtype: object

# %%
df[["ID","Name"]]
# Out:
#     ID   Name
# 0  101   John
# 1  102  Mercy
# 2  103  Akash
# 3  107  Kavin
# 4  176  Lally

# %%
df=df.drop("ID",axis=1)

# %%
df
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      54
# 2  Akash      56
# 3  Kavin      87
# 4  Lally     123

# %%
df.drop(3)
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      54
# 2  Akash      56
# 4  Lally     123

# %%
df.drop(2,axis=0)
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      54
# 3  Kavin      87
# 4  Lally     123
